# %%
t_fmri = 290 * 2.2
print(t_fmri)
fps = 25
frames = 16500
frames / fps
# Out:
# 638.0
# 660.0

# %%
vid.get_meta_data()
# Out:
# {'plugin': 'ffmpeg',
#  'nframes': inf,
#  'ffmpeg_version': '4.1-static https://johnvansickle.com/ffmpeg/ built with gcc 6.3.0 (Debian 6.3.0-18+deb9u1) 20170516',
#  'codec': 'mpeg4',
#  'pix_fmt': 'yuv420p',
#  'fps': 25.0,
#  'source_size': (720, 576),
#  'size': (720, 576),
#  'duration': 660.0}

# %%
image.min()
# Out:
# 0

# %%
import imageio
filename = 'ID1000_XVIDAVI_169.avi'
vid = imageio.get_reader(filename, 'ffmpeg')

for i, image in enumerate(vid.iter_data()):
    if i % 100 == 0:
        print(i)

metadata = vid.get_meta_data()
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-95e9a810266b> in <module>
#       3 vid = imageio.get_reader(filename, 'ffmpeg')
#       4
# ----> 5 for i, image in enumerate(vid.iter_data()):
#       6     if i % 100 == 0:
#       7         print(i)
#
# /opt/conda/lib/python3.7/site-packages/imageio/core/format.py in iter_data(self)
#     397             while i < n:
#     398                 try:
# --> 399                     im, meta = self._get_data(i)
#     400                 except StopIteration:
#     401                     return
#
# /opt/conda/lib/python3.7/site-packages/imageio/plugins/ffmpeg.py in _get_data(self, index)
#     381                 else:
#     382                     self._skip_frames(index - self._pos - 1)
# --> 383                 result, is_new = self._read_frame()
#     384                 self._pos = index
#     385                 return result, dict(new=is_new)
#
# /opt/conda/lib/python3.7/site-packages/imageio/plugins/ffmpeg.py in _read_frame(self)
#     492                 )
#     493
# --> 494             result = np.frombuffer(s, dtype=self._dtype).copy()
#     495             result = result.reshape((h, w, self._depth))
#     496             # t1 = time.time()
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.imshow(image)

# %%
image.shape
# Out:
# (576, 720, 3)
